# %%
import pandas as pd
import plotly.express as px

# Cargar datos
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)

# Análisis Exploratorio - Gráfico interactivo
fig = px.scatter(df, x="sepal_length", y="sepal_width", color="species",
                 title="Longitud y ancho del sépalo por especie")
fig.show()
# Out:
# La ejecución de celdas con 'Python 3.10.0' requiere el paquete ipykernel.
#
# Ejecute el siguiente comando para instalar 'ipykernel' en el entorno de Python. comando
#
# : '/usr/local/bin/python3.10 -m pip install ipykernel -U --user --force-reinstall'
